# %%
import csv 
import nltk
from nltk.stem import WordNetLemmatizer
import gensim.downloader as api 
from itertools import combinations

# %%
nltk.download('wordnet')
model = api.load('word2vec-google-news-300')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/rafailiavlachou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import pandas as pd 
df = pd.read_csv('../data/relations_count.csv')
df['lower_relations'] = df['relation'].apply(lambda x: x.lower().replace('_', ' '))
df = df.groupby(['lower_relations']).sum('count')
df.to_csv('../data/unique_relations.csv')

# %%
data_path = '../data/unique_relations.csv'
with open(data_path, 'r') as d:
    data = csv.reader(d)
    raw_relations = [row[0] for row in data][1:]

# %%
len(raw_relations)
# Out:
# 1461

# %%
df_new = pd.read_csv(data_path)
df_new
# Out:
#               lower_relations  count
# 0                     abandon      3
# 1              abandonment of      1
# 2                     abolish      2
# 3     accede to pressure from      1
# 4                  accelerate      1
# ...                       ...    ...
# 1456            worried about      1
# 1457              worry about      1
# 1458                    write     21
# 1459                 write on      1
# 1460                    wrote      1
#
# [1461 rows x 2 columns]

# %%
lemmatizer = WordNetLemmatizer()

# %%
df_new['lematised'] = df_new['lower_relations'].apply(lambda x: lemmatizer.lemmatize(x, 'v'))
df_new
# Out:
#               lower_relations  count                lematised
# 0                     abandon      3                  abandon
# 1              abandonment of      1           abandonment of
# 2                     abolish      2                  abolish
# 3     accede to pressure from      1  accede to pressure from
# 4                  accelerate      1               accelerate
# ...                       ...    ...                      ...
# 1456            worried about      1            worried about
# 1457              worry about      1              worry about
# 1458                    write     21                    write
# 1459                 write on      1                 write on
# 1460                    wrote      1                    write
#
# [1461 rows x 3 columns]

# %%
lemmatized_relations = [lemmatizer.lemmatize(relation, 'v') for relation in raw_relations]
mapping_1 = dict(zip(raw_relations, lemmatized_relations))
mapping_1
# Out:
# {'abandon': 'abandon',
#  'abandonment of': 'abandonment of',
#  'abolish': 'abolish',
#  'accede to pressure from': 'accede to pressure from',
#  'accelerate': 'accelerate',
#  'accept': 'accept',
#  'accept as': 'accept as',
#  'accept with': 'accept with',
#  'accepted as': 'accepted as',
#  'accepts': 'accept',
#  'access': 'access',
#  'accessing': 'access',
#  'accommodate': 'accommodate',
#  'accompanied': 'accompany',
#  'accuse': 'accuse',
#  'accused': 'accuse',
#  'accused in': 'accused in',
#  'accused of': 'accused of',
#  'achieve': 'achieve',
#  'achieved': 'achieve',
#  'acknowledge': 'acknowledge',
#  'acquiesce': 'acquiesce',
#  'acquire': 'acquire',
#  'acquired': 'acquire',
#  'acquit': 'acquit',
#  'act as checks on': 'act as checks on',
#  'acted as': 'acted as',
#  'adapt': 'adapt',
#  'add': 'add',
#  'address': 'address',
#  'addressed': 'address',
#  'adjacent to': 'adjacent to',
#  'administer': 'administer',
#  'admire': 'admire',
#  'admit': 'admit',
#  'adopt': 'adopt',
#  'advance': 'advance',
#  'advance on': 'advance on',
#  'advance to': 'advance to',
#  'adversely affect': 'adversely affect',
#  'advise': 'advise',
#  'advised against': 'advised against',
#  'advisor': 'advisor',
#  'advocate': 'advocate',
#  'advocate for': 'advocate for',
#  'advocated': 'advocate',
#  'affect': 'affect',
#  'affirm': 'affirm',
#  'against': 'against',
#  'aggravate': 'aggravate',
#  'agree': 'agree',
#  'agree to': 'agree to',
#  'agree to run for': 'agree to run for',
#  'agree to withdraw': 'agree to withdraw',
#  'agree to work': 'agree to work',
#  'aim to comply with': 'aim to comply with',
#  'alert': 'alert',
#  'align': 'align',
#  'allege': 'allege',
#  'allow': 'allow',
#  'allowed release': 'allowed release',
#  'allowing': 'allow',
#  'allude to': 'allude to',
#  'analyses': 'analyse',
#  'analyze': 'analyze',
#  'annex': 'annex',
#  'announce': 'announce',
#  'answer': 'answer',
#  'antagonize': 'antagonize',
#  'anti': 'anti',
#  'apologize for': 'apologize for',
#  'apologize to': 'apologize to',
#  'appeal': 'appeal',
#  'appeal for': 'appeal for',
#  'appeal to': 'appeal to',
#  'appealed': 'appeal',
#  'appealed to': 'appealed to',
#  'appear': 'appear',
#  'appear at': 'appear at',
#  'appear in': 'appear in',
#  'appear on': 'appear on',
#  'appearances on': 'appearances on',
#  'apply': 'apply',
#  'apply to': 'apply to',
#  'appoint': 'appoint',
#  'appoint as': 'appoint as',
#  'appointed': 'appoint',
#  'appointed as': 'appointed as',
#  'approach': 'approach',
#  'approached': 'approach',
#  'approve': 'approve',
#  'argue': 'argue',
#  'argue against': 'argue against',
#  'argue for': 'argue for',
#  'arise': 'arise',
#  'arm and train': 'arm and train',
#  'arouse': 'arouse',
#  'arrange': 'arrange',
#  'arrest warrant': 'arrest warrant',
#  'arrested by': 'arrested by',
#  'arrive in': 'arrive in',
#  'ask': 'ask',
#  'ask about': 'ask about',
#  'assassination': 'assassination',
#  'assemble': 'assemble',
#  'assert': 'assert',
#  'assert right to intervene': 'assert right to intervene',
#  'assess': 'assess',
#  'assign': 'assign',
#  'assigned to': 'assigned to',
#  'assist': 'assist',
#  'assume': 'assume',
#  'assume ownership': 'assume ownership',
#  'assumed': 'assume',
#  'assumed position': 'assumed position',
#  'assumes': 'assume',
#  'assured of': 'assured of',
#  'attack': 'attack',
#  'attempt': 'attempt',
#  'attempt occupation': 'attempt occupation',
#  'attempted rollback halted by': 'attempted rollback halted by',
#  'attempted to recruit': 'attempted to recruit',
#  'attend': 'attend',
#  'attends': 'attend',
#  'attract': 'attract',
#  'attribute': 'attribute',
#  'auctioned': 'auction',
#  'author': 'author',
#  'authorize': 'authorize',
#  'average': 'average',
#  'avert': 'avert',
#  'avoid': 'avoid',
#  'avoid mention of': 'avoid mention of',
#  'avoided discussions about': 'avoided discussions about',
#  'award': 'award',
#  'awarded': 'award',
#  'aware of': 'aware of',
#  'back': 'back',
#  'back down': 'back down',
#  'backed': 'back',
#  'balance': 'balance',
#  'ban': 'ban',
#  'baptize': 'baptize',
#  'bar': 'bar',
#  'bask in': 'bask in',
#  'be active in': 'be active in',
#  'be at odds with': 'be at odds with',
#  'be critical of': 'be critical of',
#  'be good for': 'be good for',
#  'be in': 'be in',
#  'be with': 'be with',
#  'be worth': 'be worth',
#  'became': 'become',
#  'became active in': 'became active in',
#  'become': 'become',
#  'become effective': 'become effective',
#  'begin': 'begin',
#  'begin career in': 'begin career in',
#  'begin construction in': 'begin construction in',
#  'believe': 'believe',
#  'believe in': 'believe in',
#  'belonging to': 'belonging to',
#  'benefit from': 'benefit from',
#  'bill': 'bill',
#  'blame': 'blame',
#  'blind to': 'blind to',
#  'block': 'block',
#  'blocked': 'block',
#  'bolster': 'bolster',
#  'boost': 'boost',
#  'born in': 'born in',
#  'born on': 'born on',
#  'borrow': 'borrow',
#  'bought': 'buy',
#  'break': 'break',
#  'bring': 'bring',
#  'bring in': 'bring in',
#  'bring into violation': 'bring into violation',
#  'broke': 'break',
#  'build': 'build',
#  'built for': 'built for',
#  'burnt': 'burn',
#  'business associate of': 'business associate of',
#  'buy': 'buy',
#  'call': 'call',
#  'call for': 'call for',
#  'call for end': 'call for end',
#  'call for resignation': 'call for resignation',
#  'call for restrictions on': 'call for restrictions on',
#  'call on': 'call on',
#  'campaign': 'campaign',
#  'campaign against': 'campaign against',
#  'campaign for': 'campaign for',
#  'campaigned for': 'campaigned for',
#  'campaigns against': 'campaigns against',
#  'cancel': 'cancel',
#  'capitalize on': 'capitalize on',
#  'capture': 'capture',
#  'care': 'care',
#  'cared by': 'cared by',
#  'carry': 'carry',
#  'carry out': 'carry out',
#  'cast': 'cast',
#  'cast vote in support of': 'cast vote in support of',
#  'categorize': 'categorize',
#  'cause': 'cause',
#  'caused': 'cause',
#  'cease': 'cease',
#  'celebrate': 'celebrate',
#  'cement': 'cement',
#  'centralise': 'centralise',
#  'certified': 'certify',
#  'chair': 'chair',
#  'change': 'change',
#  'characterize': 'characterize',
#  'characterized by': 'characterized by',
#  'charge': 'charge',
#  'charge with': 'charge with',
#  'charged with': 'charged with',
#  'cheat': 'cheat',
#  'check': 'check',
#  'child of': 'child of',
#  'choose': 'choose',
#  'circumvention': 'circumvention',
#  'cite': 'cite',
#  'cited': 'cite',
#  'claim': 'claim',
#  'claim responsibility for': 'claim responsibility for',
#  'clarify': 'clarify',
#  'classify': 'classify',
#  'clear': 'clear',
#  'cleared': 'clear',
#  'clerk for': 'clerk for',
#  'clerked at': 'clerked at',
#  'close': 'close',
#  'co-authored': 'co-author',
#  'co-found': 'co-found',
#  'co-founded': 'co-founded',
#  'co-host': 'co-host',
#  'co-opt': 'co-opt',
#  'co-produce': 'co-produce',
#  'co-producer': 'co-producer',
#  'co-sponsor': 'co-sponsor',
#  'coalesce around': 'coalesce around',
#  'codify': 'codify',
#  'cofound': 'cofound',
#  'coincide with': 'coincide with',
#  'collaborate': 'collaborate',
#  'collaborate closely with': 'collaborate closely with',
#  'collapse': 'collapse',
#  'collect': 'collect',
#  'collected': 'collect',
#  'combat': 'combat',
#  'combine': 'combine',
#  'combine with': 'combine with',
#  'come from': 'come from',
#  'commence': 'commence',
#  'commend': 'commend',
#  'comment on': 'comment on',
#  'commentary in': 'commentary in',
#  'commission': 'commission',
#  'commit': 'commit',
#  'commit to': 'commit to',
#  'committed to': 'committed to',
#  'communicate': 'communicate',
#  'communicate with': 'communicate with',
#  'commute': 'commute',
#  'compare': 'compare',
#  'compare to': 'compare to',
#  'compete': 'compete',
#  'compete against': 'compete against',
#  'compete for': 'compete for',
#  'complete': 'complete',
#  'complete denuclearization': 'complete denuclearization',
#  'comply': 'comply',
#  'comply with': 'comply with',
#  'compose': 'compose',
#  'composed of': 'composed of',
#  'compromise': 'compromise',
#  'concede': 'concede',
#  'concede to': 'concede to',
#  'concern': 'concern',
#  'concerned about': 'concerned about',
#  'concerned with': 'concerned with',
#  'conclude': 'conclude',
#  'condemn': 'condemn',
#  'condemned as': 'condemned as',
#  'conduct': 'conduct',
#  'conducted by': 'conducted by',
#  'confident in': 'confident in',
#  'confirm': 'confirm',
#  'confirms': 'confirm',
#  'conflict': 'conflict',
#  'conflict with': 'conflict with',
#  'confront': 'confront',
#  'confronted by': 'confronted by',
#  'congratulate': 'congratulate',
#  'connect with': 'connect with',
#  'consider': 'consider',
#  'considered': 'consider',
#  'considers': 'consider',
#  'consist of': 'consist of',
#  'consists of': 'consists of',
#  'consolidate': 'consolidate',
#  'construct': 'construct',
#  'consult': 'consult',
#  'consultant': 'consultant',
#  'consultant to': 'consultant to',
#  'consummate': 'consummate',
#  'contact': 'contact',
#  'contain': 'contain',
#  'contemplated': 'contemplate',
#  'contend': 'contend',
#  'continue': 'continue',
#  'contradict': 'contradict',
#  'contrast': 'contrast',
#  'contribute to': 'contribute to',
#  'contributed to': 'contributed to',
#  'control': 'control',
#  'convene': 'convene',
#  'convert': 'convert',
#  'convict': 'convict',
#  'convicted of': 'convicted of',
#  'convince': 'convince',
#  'cooperate': 'cooperate',
#  'copy': 'copy',
#  'correlate': 'correlate',
#  'cosponsor': 'cosponsor',
#  'cost': 'cost',
#  'could build': 'could build',
#  'count': 'count',
#  'counted on': 'counted on',
#  'countered': 'counter',
#  'countersue': 'countersue',
#  'countersued': 'countersued',
#  'cover': 'cover',
#  'cover up': 'cover up',
#  'create': 'create',
#  'created': 'create',
#  'credit': 'credit',
#  'credits': 'credit',
#  'criminalize': 'criminalize',
#  'criticism of': 'criticism of',
#  'criticize': 'criticize',
#  'criticizes': 'criticize',
#  'critique': 'critique',
#  'cross': 'cross',
#  'cultivate': 'cultivate',
#  'curate': 'curate',
#  'cut': 'cut',
#  'cut back': 'cut back',
#  'cut out': 'cut out',
#  'cut ties with': 'cut ties with',
#  'damage': 'damage',
#  'date': 'date',
#  'decide': 'decide',
#  'declare': 'declare',
#  'declare independence': 'declare independence',
#  'declare unconstitutional': 'declare unconstitutional',
#  'declared': 'declare',
#  'decline': 'decline',
#  'decline in support for': 'decline in support for',
#  'decorated with': 'decorated with',
#  'decrease': 'decrease',
#  'deem': 'deem',
#  'deepen': 'deepen',
#  'default': 'default',
#  'defeat': 'defeat',
#  'defeated': 'defeat',
#  'defeated by': 'defeated by',
#  'defeated in': 'defeated in',
#  'defeating': 'defeat',
#  'defend': 'defend',
#  'defended': 'defend',
#  'defender of': 'defender of',
#  'defer': 'defer',
#  'define': 'define',
#  'defraud': 'defraud',
#  'delay': 'delay',
#  'delegate': 'delegate',
#  'delete': 'delete',
#  'deliver': 'deliver',
#  'delivered': 'deliver',
#  'demand': 'demand',
#  'demand investigation': 'demand investigation',
#  'demand resignation': 'demand resignation',
#  'denied': 'deny',
#  'denigrate': 'denigrate',
#  'denounce': 'denounce',
#  'deny': 'deny',
#  'deny entry to': 'deny entry to',
#  'deplete': 'deplete',
#  'deploy': 'deploy',
#  'derail': 'derail',
#  'deregulate': 'deregulate',
#  'descend from': 'descend from',
#  'descended from': 'descended from',
#  'describe': 'describe',
#  'describe as': 'describe as',
#  'described as': 'described as',
#  'design': 'design',
#  'designate': 'designate',
#  'desire': 'desire',
#  'despise': 'despise',
#  'destroy': 'destroy',
#  'detain': 'detain',
#  'determine': 'determine',
#  'develop': 'develop',
#  'developed': 'develop',
#  'deviate from': 'deviate from',
#  'dictate': 'dictate',
#  'did well in': 'did well in',
#  'die in': 'die in',
#  'direct': 'direct',
#  'disable': 'disable',
#  'disagree with': 'disagree with',
#  'disappeared on': 'disappeared on',
#  'disapprove': 'disapprove',
#  'disburse': 'disburse',
#  'discipline': 'discipline',
#  'disclose': 'disclose',
#  'discourage': 'discourage',
#  'discover': 'discover',
#  'discredit': 'discredit',
#  'discuss': 'discuss',
#  'disdain': 'disdain',
#  'disliked': 'dislike',
#  'dismiss': 'dismiss',
#  'dismissed': 'dismiss',
#  'disparage': 'disparage',
#  'dispatch': 'dispatch',
#  'dispute': 'dispute',
#  'disputed': 'dispute',
#  'disqualify': 'disqualify',
#  'disregard': 'disregard',
#  'disrupt': 'disrupt',
#  'dissolve': 'dissolve',
#  'distant from': 'distant from',
#  'distribute': 'distribute',
#  'divert': 'divert',
#  'divide': 'divide',
#  'divide into': 'divide into',
#  'divide on': 'divide on',
#  'divorce': 'divorce',
#  'do better among': 'do better among',
#  'document': 'document',
#  'dominance of': 'dominance of',
#  'dominate': 'dominate',
#  'dominated': 'dominate',
#  'donate': 'donate',
#  'donated to': 'donated to',
#  'donations': 'donations',
#  'double': 'double',
#  'downplay': 'downplay',
#  'draft': 'draft',
#  'drag': 'drag',
#  'draw': 'draw',
#  'draw upon': 'draw upon',
#  'drive': 'drive',
#  'drop': 'drop',
#  'drop out': 'drop out',
#  'earn': 'earn',
#  'earned': 'earn',
#  'echo': 'echo',
#  'elect': 'elect',
#  'elected': 'elect',
#  'elected as': 'elected as',
#  'elected to': 'elected to',
#  'elects': 'elect',
#  'elevate': 'elevate',
#  'eliminate': 'eliminate',
#  'embark on': 'embark on',
#  'embrace': 'embrace',
#  'emerge from': 'emerge from',
#  'emigrate': 'emigrate',
#  'emigrated from': 'emigrated from',
#  'emigrated to': 'emigrated to',
#  'emphasis': 'emphasis',
#  'emphasis on': 'emphasis on',
#  'emphasize': 'emphasize',
#  'employ': 'employ',
#  'employed at': 'employed at',
#  'empower': 'empower',
#  'enact': 'enact',
#  'encourage': 'encourage',
#  'encourages': 'encourage',
#  'end': 'end',
#  'endorse': 'endorse',
#  'enforce': 'enforce',
#  'enforced by': 'enforced by',
#  'engage': 'engage',
#  'engage in': 'engage in',
#  'engender': 'engender',
#  'enlisted': 'enlist',
#  'enroll': 'enroll',
#  'enrolled in': 'enrolled in',
#  'ensure': 'ensure',
#  'ensuring': 'ensure',
#  'enter': 'enter',
#  'entered': 'enter',
#  'entrance into': 'entrance into',
#  'envelop': 'envelop',
#  'equity stake': 'equity stake',
#  'erase': 'erase',
#  'erode': 'erode',
#  'escalate': 'escalate',
#  'establish': 'establish',
#  'estimate': 'estimate',
#  'evade': 'evade',
#  'examine': 'examine',
#  'exceed': 'exceed',
#  'exchange': 'exchange',
#  'exclude': 'exclude',
#  'execute': 'execute',
#  'exemplify': 'exemplify',
#  'exempt': 'exempt',
#  'exercise': 'exercise',
#  'exit': 'exit',
#  'exonerate': 'exonerate',
#  'expand': 'expand',
#  'expand at': 'expand at',
#  'expand lead': 'expand lead',
#  'expand upon': 'expand upon',
#  'expect': 'expect',
#  'expel': 'expel',
#  'experience': 'experience',
#  'explain': 'explain',
#  'export': 'export',
#  'expose': 'expose',
#  'express': 'express',
#  'express admiration for': 'express admiration for',
#  'express desire': 'express desire',
#  'express gratitude to': 'express gratitude to',
#  'express support for': 'express support for',
#  'express willingness': 'express willingness',
#  'expressed support for': 'expressed support for',
#  'expunge': 'expunge',
#  'extend': 'extend',
#  'extensive': 'extensive',
#  'face': 'face',
#  'face off with': 'face off with',
#  'face opposition from': 'face opposition from',
#  'faced': 'face',
#  'faced criticism': 'faced criticism',
#  'faces': 'face',
#  'facilitate': 'facilitate',
#  'facilitates': 'facilitate',
#  'fail': 'fail',
#  'fail to gain approval from': 'fail to gain approval from',
#  'fail to produce': 'fail to produce',
#  'failed to protect': 'failed to protect',
#  'failure to prevent': 'failure to prevent',
#  'falter': 'falter',
#  'fan of': 'fan of',
#  'favor': 'favor',
#  'fear': 'fear',
#  'feature': 'feature',
#  'featured in': 'featured in',
#  'federalize': 'federalize',
#  'fell': 'fell',
#  'fight': 'fight',
#  'file': 'file',
#  'file complaint': 'file complaint',
#  'file complaint against': 'file complaint against',
#  'file for': 'file for',
#  'file for bankruptcy': 'file for bankruptcy',
#  'filed for': 'filed for',
#  'filed suit against': 'filed suit against',
#  'filled': 'fill',
#  'finance': 'finance',
#  'find': 'find',
#  'fine': 'fine',
#  'finish': 'finish',
#  'finish behind': 'finish behind',
#  'fire': 'fire',
#  'first lady of': 'first lady of',
#  'flee': 'flee',
#  'flower': 'flower',
#  'fly': 'fly',
#  'focus': 'focus',
#  'focus on': 'focus on',
#  'fold': 'fold',
#  'follow': 'follow',
#  'following': 'follow',
#  'for': 'for',
#  'force': 'force',
#  'forced by': 'forced by',
#  'forge': 'forge',
#  'forged': 'forge',
#  'form': 'form',
#  'formalize': 'formalize',
#  'formed': 'form',
#  'formulate': 'formulate',
#  'forward': 'forward',
#  'foster': 'foster',
#  'fought against': 'fought against',
#  'found': 'find',
#  'found guilty on': 'found guilty on',
#  'found liable for': 'found liable for',
#  'frame': 'frame',
#  'friend of': 'friend of',
#  'friend with': 'friend with',
#  'friendship': 'friendship',
#  'frustrate': 'frustrate',
#  'fund': 'fund',
#  'furnish': 'furnish',
#  'gain': 'gain',
#  'gain influence': 'gain influence',
#  'garner': 'garner',
#  'gather': 'gather',
#  'gathered in': 'gathered in',
#  'gave': 'give',
#  'gave up': 'gave up',
#  'generate': 'generate',
#  'give': 'give',
#  'give birth': 'give birth',
#  'give eulogy': 'give eulogy',
#  'give speech at': 'give speech at',
#  'give up': 'give up',
#  'gives power to': 'gives power to',
#  'go along with': 'go along with',
#  'go bankrupt': 'go bankrupt',
#  'governed by': 'governed by',
#  'graduate': 'graduate',
#  'graduate from': 'graduate from',
#  'graduate in': 'graduate in',
#  'graduate of': 'graduate of',
#  'graduate student at': 'graduate student at',
#  'graduated from': 'graduated from',
#  'grant': 'grant',
#  'grapple with': 'grapple with',
#  'greet': 'greet',
#  'grow': 'grow',
#  'grow faster than': 'grow faster than',
#  'growing emissions': 'growing emissions',
#  'guarantee': 'guarantee',
#  'guaranteed': 'guarantee',
#  'guarded by': 'guarded by',
#  'guest appearances on': 'guest appearances on',
#  'guide': 'guide',
#  'hack': 'hack',
#  'had': 'have',
#  'hail': 'hail',
#  'halt': 'halt',
#  'halve': 'halve',
#  'hand over to': 'hand over to',
#  'handle': 'handle',
#  'handled': 'handle',
#  'has': 'have',
#  'has ancestor': 'has ancestor',
#  'has seniority over': 'has seniority over',
#  'have': 'have',
#  'have favorable views': 'have favorable views',
#  'have right to': 'have right to',
#  'headquarters in': 'headquarters in',
#  'hear': 'hear',
#  'hear about': 'hear about',
#  'held': 'hold',
#  'held titles of': 'held titles of',
#  'help': 'help',
#  'help pass': 'help pass',
#  'helped': 'help',
#  'hide': 'hide',
#  'higher than': 'higher than',
#  'highlight': 'highlight',
#  'hire': 'hire',
#  'hired': 'hire',
#  'hires': 'hire',
#  'hobble': 'hobble',
#  'hold': 'hold',
#  'honeymoon at': 'honeymoon at',
#  'honor': 'honor',
#  'hope': 'hope',
#  'hospitalized at': 'hospitalized at',
#  'hospitalized for': 'hospitalized for',
#  'host': 'host',
#  'hosts': 'host',
#  'hurt': 'hurt',
#  'identify': 'identify',
#  'identify as': 'identify as',
#  'ignore': 'ignore',
#  'illustrate': 'illustrate',
#  'impact': 'impact',
#  'impeach': 'impeach',
#  'implement': 'implement',
#  'imply': 'imply',
#  'impose': 'impose',
#  'impose limitations on': 'impose limitations on',
#  'improve': 'improve',
#  'incensed by': 'incensed by',
#  'include': 'include',
#  'incorporate': 'incorporate',
#  'increase': 'increase',
#  'indicate': 'indicate',
#  'indict': 'indict',
#  'indicted on': 'indicted on',
#  'influence': 'influence',
#  'inform': 'inform',
#  'inherit': 'inherit',
#  'inhibit': 'inhibit',
#  'initiate': 'initiate',
#  'injured in confrontations with': 'injured in confrontations with',
#  'insist': 'insist',
#  'insist on leading': 'insist on leading',
#  'inspect': 'inspect',
#  'instruct': 'instruct',
#  'insured': 'insure',
#  'intensify': 'intensify',
#  'intercept': 'intercept',
#  'interested in': 'interested in',
#  'interfere': 'interfere',
#  'intern': 'intern',
#  'interpret': 'interpret',
#  'intervene': 'intervene',
#  'intervene in': 'intervene in',
#  'intervention': 'intervention',
#  'interview': 'interview',
#  'intimidate': 'intimidate',
#  'introduce': 'introduce',
#  'introduce to': 'introduce to',
#  'introduced': 'introduce',
#  'invade': 'invade',
#  'invalidate': 'invalidate',
#  'invasion': 'invasion',
#  'invest': 'invest',
#  'investigate': 'investigate',
#  'investigated by': 'investigated by',
#  'invests in': 'invests in',
#  'invite': 'invite',
#  'invited': 'invite',
#  'invited to speak at': 'invited to speak at',
#  'involve': 'involve',
#  'involved': 'involve',
#  'involved in': 'involved in',
#  'involved with': 'involved with',
#  'is': 'be',
#  'is candidate in': 'is candidate in',
#  'is child of': 'is child of',
#  'is different from': 'is different from',
#  'is first without': 'is first without',
#  'is grandchild of': 'is grandchild of',
#  'is located in': 'is located in',
#  'is member of': 'is member of',
#  'is replaced by': 'is replaced by',
#  'is sibling of': 'is sibling of',
#  'issue': 'issue',
#  'issued': 'issue',
#  'join': 'join',
#  'joke': 'joke',
#  'justify': 'justify',
#  'juxtapose': 'juxtapose',
#  'keep': 'keep',
#  'kill': 'kill',
#  'killed': 'kill',
#  'killed by': 'killed by',
#  'know': 'know',
#  'label': 'label',
#  'lack': 'lack',
#  'lack authority': 'lack authority',
#  'laugh': 'laugh',
#  'launch': 'launch',
#  'lay groundwork for': 'lay groundwork for',
#  'lead': 'lead',
#  'lead to': 'lead to',
#  'leader of': 'leader of',
#  'leading foreign policy figure': 'leading foreign policy figure',
#  'learn': 'learn',
#  'learned of': 'learned of',
#  'leave': 'leave',
#  'led': 'lead',
#  'left office without': 'left office without',
#  'legalized': 'legalize',
#  'lend': 'lend',
#  'lend name to': 'lend name to',
#  'lessen': 'lessen',
#  'leverage': 'leverage',
#  'liberate': 'liberate',
#  'license': 'license',
#  'lied': 'lie',
#  'lied to': 'lied to',
#  'lift': 'lift',
#  'like': 'like',
#  'likened': 'liken',
#  'likened to': 'likened to',
#  'limit': 'limit',
#  'link to': 'link to',
#  'liquidated': 'liquidate',
#  'list': 'list',
#  'litigate': 'litigate',
#  'live': 'live',
#  'live at': 'live at',
#  'live in': 'live in',
#  'live with': 'live with',
#  'loaning money to': 'loaning money to',
#  'lobby': 'lobby',
#  'lobby against': 'lobby against',
#  'locate in': 'locate in',
#  'lose': 'lose',
#  'lose to': 'lose to',
#  'loss': 'loss',
#  'lost': 'lose',
#  'lower': 'lower',
#  'made': 'make',
#  'mainstream of': 'mainstream of',
#  'maintain': 'maintain',
#  'make': 'make',
#  'make gains in': 'make gains in',
#  'make progress': 'make progress',
#  'make public': 'make public',
#  'make trips': 'make trips',
#  'manage': 'manage',
#  'mandate': 'mandate',
#  'manipulate': 'manipulate',
#  'mark': 'mark',
#  'mark as': 'mark as',
#  'married': 'marry',
#  'married at': 'married at',
#  'married in': 'married in',
#  'married on': 'married on',
#  'married to': 'married to',
#  'marry': 'marry',
#  'measure': 'measure',
#  'mediates': 'mediate',
#  'meet': 'meet',
#  'meet at': 'meet at',
#  'meet with': 'meet with',
#  'meeting': 'meet',
#  'member of': 'member of',
#  'mentions': 'mention',
#  'mentor': 'mentor',
#  'merge': 'merge',
#  'met': 'meet',
#  'met in': 'met in',
#  'minimize': 'minimize',
#  'mirror': 'mirror',
#  'misattribute': 'misattribute',
#  'miscast': 'miscast',
#  'mischaracterize': 'mischaracterize',
#  'mishandle': 'mishandle',
#  'misrepresent': 'misrepresent',
#  'misuse': 'misuse',
#  'mitigate': 'mitigate',
#  'mobilize': 'mobilize',
#  'modernize': 'modernize',
#  'monitor': 'monitor',
#  'move': 'move',
#  'move closer to': 'move closer to',
#  'move from': 'move from',
#  'move in': 'move in',
#  'move quickly': 'move quickly',
#  'move to': 'move to',
#  'moved to': 'moved to',
#  'murder': 'murder',
#  'name': 'name',
#  'named': 'name',
#  'need': 'need',
#  'negative impact on': 'negative impact on',
#  'negotiate': 'negotiate',
#  'negotiate with': 'negotiate with',
#  'net worth': 'net worth',
#  'never used': 'never used',
#  'no nominee for': 'no nominee for',
#  'nominate': 'nominate',
#  'nominated': 'nominate',
#  'nominated by': 'nominated by',
#  'nomination': 'nomination',
#  'normalize relations': 'normalize relations',
#  'not advocate': 'not advocate',
#  'not aware of': 'not aware of',
#  'not confirm': 'not confirm',
#  'not do business': 'not do business',
#  'not eligible for': 'not eligible for',
#  'not engage': 'not engage',
#  'not greet': 'not greet',
#  'not ratify': 'not ratify',
#  'not release': 'not release',
#  'not secure': 'not secure',
#  'note': 'note',
#  'noted': 'note',
#  'notice': 'notice',
#  'notify': 'notify',
#  'nurture': 'nurture',
#  'observe': 'observe',
#  'obstruct': 'obstruct',
#  'obtain': 'obtain',
#  'obtained': 'obtain',
#  'occur': 'occur',
#  'offer': 'offer',
#  'offshore': 'offshore',
#  'open': 'open',
#  'open to': 'open to',
#  'open up': 'open up',
#  'opened': 'open',
#  'operate in': 'operate in',
#  'oppose': 'oppose',
#  'opposed': 'oppose',
#  'opted for': 'opted for',
#  'order': 'order',
#  'ordered by': 'ordered by',
#  'ordered to pay': 'ordered to pay',
#  'organize': 'organize',
#  'originate from': 'originate from',
#  'oust': 'oust',
#  'outline': 'outline',
#  'outpaced': 'outpace',
#  'overcome': 'overcome',
#  'overestimate': 'overestimate',
#  'overhaul': 'overhaul',
#  'oversee': 'oversee',
#  'overtake': 'overtake',
#  'overthrown': 'overthrow',
#  'overturn': 'overturn',
#  'overturned by': 'overturned by',
#  'owe': 'owe',
#  'own': 'own',
#  'pack': 'pack',
#  'pardon': 'pardon',
#  'part of': 'part of',
#  'partially close': 'partially close',
#  'participate': 'participate',
#  'participate in': 'participate in',
#  'participated in': 'participated in',
#  'participates in': 'participates in',
#  'partner with': 'partner with',
#  'partner-in-charge': 'partner-in-charge',
#  'partnership with': 'partnership with',
#  'pass': 'pass',
#  'pass to': 'pass to',
#  'pay': 'pay',
#  'perception of': 'perception of',
#  'perform better in': 'perform better in',
#  'performance on': 'performance on',
#  'permit': 'permit',
#  'persecute': 'persecute',
#  'persuade': 'persuade',
#  'persuading': 'persuade',
#  'pick up': 'pick up',
#  'place': 'place',
#  'place at apex of': 'place at apex of',
#  'plan': 'plan',
#  'plan for': 'plan for',
#  'plant': 'plant',
#  'play': 'play',
#  'play key role in': 'play key role in',
#  'play role in': 'play role in',
#  'plead': 'plead',
#  'plead guilty to': 'plead guilty to',
#  'pledge': 'pledge',
#  'points to': 'points to',
#  'poisoned with': 'poisoned with',
#  'polarize': 'polarize',
#  'pollute': 'pollute',
#  'portray': 'portray',
#  'pose with': 'pose with',
#  'positive impact on': 'positive impact on',
#  'possess': 'possess',
#  'posted': 'post',
#  'postpone': 'postpone',
#  'practice': 'practice',
#  'practicing': 'practice',
#  'practise': 'practise',
#  'praise': 'praise',
#  'precede': 'precede',
#  'predict': 'predict',
#  'prefer': 'prefer',
#  'preferred': 'prefer',
#  'prefers': 'prefer',
#  'prejudice': 'prejudice',
#  'prepare for': 'prepare for',
#  'presence': 'presence',
#  'present': 'present',
#  'presented': 'present',
#  'preside over': 'preside over',
#  'president of': 'president of',
#  'press': 'press',
#  'pressure': 'pressure',
#  'pressured': 'pressure',
#  'pretend': 'pretend',
#  'prevent': 'prevent',
#  'previous marriage': 'previous marriage',
#  'prioritize': 'prioritize',
#  'probes': 'probe',
#  'process': 'process',
#  'produce': 'produce',
#  'profit from': 'profit from',
#  'prohibit': 'prohibit',
#  'promise': 'promise',
#  'promote': 'promote',
#  'prompt': 'prompt',
#  'proponent of': 'proponent of',
#  'propose': 'propose',
#  'propose to': 'propose to',
#  'proposed': 'propose',
#  'proposing': 'propose',
#  'prosecute': 'prosecute',
#  'protect': 'protect',
#  'protest': 'protest',
#  'protest against': 'protest against',
#  'prove': 'prove',
#  'prove to be': 'prove to be',
#  ...}

# %%
words = list(set(lemmatized_relations))

words = [word for word in words if word in model]

similarities = {}
for word1, word2 in combinations(words, 2):
    if word1 != word2:
        similarity = model.similarity(word1, word2)
        if similarity > 0.7:
            similarities[(word1, word2)] = similarity

sorted_similarities = sorted(similarities.items(), key=lambda item: item[1], reverse=True)


for (word1, word2), similarity in sorted_similarities:
    print(f"Similarity between '{word1}' and '{word2}': {similarity:.4f}")
# Out:
# Similarity between 'convince' and 'persuade': 0.8929
# Similarity between 'increase' and 'decrease': 0.8370
# Similarity between 'safeguard' and 'protect': 0.8329
# Similarity between 'sell' and 'buy': 0.8308
# Similarity between 'categorize' and 'classify': 0.8047
# Similarity between 'denounce' and 'condemn': 0.8003
# Similarity between 'minimize' and 'mitigate': 0.7943
# Similarity between 'lessen' and 'minimize': 0.7697
# Similarity between 'purchase' and 'buy': 0.7640
# Similarity between 'lessen' and 'reduce': 0.7530
# Similarity between 'indicate' and 'suggest': 0.7501
# Similarity between 'supervise' and 'oversee': 0.7463
# Similarity between 'recognize' and 'acknowledge': 0.7424
# Similarity between 'build' and 'construct': 0.7395
# Similarity between 'vow' and 'pledge': 0.7381
# Similarity between 'know' and 'tell': 0.7357
# Similarity between 'think' and 'know': 0.7344
# Similarity between 'reaffirm' and 'reiterate': 0.7286
# Similarity between 'minimize' and 'reduce': 0.7281
# Similarity between 'erode' and 'weaken': 0.7256
# Similarity between 'begin' and 'commence': 0.7244
# Similarity between 'believe' and 'say': 0.7189
# Similarity between 'reaffirm' and 'affirm': 0.7183
# Similarity between 'strengthen' and 'bolster': 0.7159
# Similarity between 'boost' and 'bolster': 0.7134
# Similarity between 'cancel' and 'postpone': 0.7119
# Similarity between 'undermine' and 'erode': 0.7116
# Similarity between 'characterize' and 'describe': 0.7113
# Similarity between 'determine' and 'assess': 0.7102
# Similarity between 'despise' and 'dislike': 0.7094
# Similarity between 'undermine' and 'weaken': 0.7078
# Similarity between 'contend' and 'argue': 0.7019

# %%
sorted_similarities
# Out:
# [(('convince', 'persuade'), 0.89288),
#  (('increase', 'decrease'), 0.8370319),
#  (('safeguard', 'protect'), 0.83287936),
#  (('sell', 'buy'), 0.8308461),
#  (('categorize', 'classify'), 0.8046503),
#  (('denounce', 'condemn'), 0.80032325),
#  (('minimize', 'mitigate'), 0.7943238),
#  (('lessen', 'minimize'), 0.76968896),
#  (('purchase', 'buy'), 0.7639905),
#  (('lessen', 'reduce'), 0.75301445),
#  (('indicate', 'suggest'), 0.7500874),
#  (('supervise', 'oversee'), 0.74632823),
#  (('recognize', 'acknowledge'), 0.74235857),
#  (('build', 'construct'), 0.7394898),
#  (('vow', 'pledge'), 0.7381013),
#  (('know', 'tell'), 0.7356717),
#  (('think', 'know'), 0.7344213),
#  (('reaffirm', 'reiterate'), 0.72863954),
#  (('minimize', 'reduce'), 0.72813696),
#  (('erode', 'weaken'), 0.72559845),
#  (('begin', 'commence'), 0.7244425),
#  (('believe', 'say'), 0.7188932),
#  (('reaffirm', 'affirm'), 0.71827835),
#  (('strengthen', 'bolster'), 0.7159493),
#  (('boost', 'bolster'), 0.7133502),
#  (('cancel', 'postpone'), 0.71189785),
#  (('undermine', 'erode'), 0.7116076),
#  (('characterize', 'describe'), 0.7112592),
#  (('determine', 'assess'), 0.71016425),
#  (('despise', 'dislike'), 0.70937306),
#  (('undermine', 'weaken'), 0.707797),
#  (('contend', 'argue'), 0.7018579)]

# %%
len(sorted_similarities)
# Out:
# 32

# %%
data_path = '../data/unique_relations.csv'
with open(data_path, 'r') as d:
    data = csv.reader(d)
    scores = [row[1] for row in data][1:]
relation_counts = dict(zip(raw_relations, scores))
lemma_counts = {}
for r in relation_counts:
    lemma_counts[mapping_1[r]] = relation_counts[r]

# %%
pairs = [i[0] for i in sorted_similarities]
mapping_2 = {}
for pair in pairs:
    mapping_2[pair[0]] = pair[1]
print(mapping_2)
# Out:
# {'convince': 'persuade', 'increase': 'decrease', 'safeguard': 'protect', 'sell': 'buy', 'categorize': 'classify', 'denounce': 'condemn', 'minimize': 'reduce', 'lessen': 'reduce', 'purchase': 'buy', 'indicate': 'suggest', 'supervise': 'oversee', 'recognize': 'acknowledge', 'build': 'construct', 'vow': 'pledge', 'know': 'tell', 'think': 'know', 'reaffirm': 'affirm', 'erode': 'weaken', 'begin': 'commence', 'believe': 'say', 'strengthen': 'bolster', 'boost': 'bolster', 'cancel': 'postpone', 'undermine': 'weaken', 'characterize': 'describe', 'determine': 'assess', 'despise': 'dislike', 'contend': 'argue'}

# %%
final = {}
for r in raw_relations:
    tmp = mapping_1[r]
    if tmp in mapping_2:
        final[r]= mapping_2[tmp]
    else:
        final[r] = tmp

# %%
len(final)
# Out:
# 1461

# %%
unique_relations = set(final.values())
len(unique_relations) # was 1491
# Out:
# 1306

# %%
df_new['processed relations'] = df_new['lower_relations'].apply(lambda x: final[x])
df_new
# Out:
#               lower_relations  count                lematised  \
# 0                     abandon      3                  abandon
# 1              abandonment of      1           abandonment of
# 2                     abolish      2                  abolish
# 3     accede to pressure from      1  accede to pressure from
# 4                  accelerate      1               accelerate
# ...                       ...    ...                      ...
# 1456            worried about      1            worried about
# 1457              worry about      1              worry about
# 1458                    write     21                    write
# 1459                 write on      1                 write on
# 1460                    wrote      1                    write
#
#           processed relations
# 0                     abandon
# 1              abandonment of
# 2                     abolish
# 3     accede to pressure from
# 4                  accelerate
# ...                       ...
# 1456            worried about
# 1457              worry about
# 1458                    write
# 1459                 write on
# 1460                    write
#
# [1461 rows x 4 columns]

# %%
final['recognize']
# Out:
# 'acknowledge'

# %%
with open("relation_mapping.csv", "w") as f:
   for key in final.keys():
        f.write("%s,%s\n"%(key,final[key]))

# %% [markdown]
# Same analysis with sentence embeddings instead of work embeddings.

# %%
from sentence_transformers import SentenceTransformer
model2 = SentenceTransformer("all-MiniLM-L6-v2")

# %%
words2 = list(set(lemmatized_relations))

# %%
word_embeddings = model2.encode(words2)

# %%
from sentence_transformers import util
similarities = {}
all_pairs = []
semantic_scores = util.semantic_search(word_embeddings, word_embeddings)
for i, score in enumerate(semantic_scores):
    pair = (words2[i], words2[score[1]['corpus_id']])
    a, b = pair
    if a == b:
        print('duplicates')
    if set(pair) not in all_pairs:
        all_pairs.append(set(pair))
        similarity = score[1]['score']
        if similarity > 0.7:
            similarities[pair] = similarity

sorted_similarities2 = sorted(similarities.items(), key=lambda item: item[1], reverse=True)
print(len(sorted_similarities2))
# Out:
# 340

# %%
sorted_similarities2
# Out:
# [(('resign', 'resign from'), 0.9724125266075134),
#  (('withdraw from', 'withdraw'), 0.965355396270752),
#  (('comply with', 'comply'), 0.9633784294128418),
#  (('sworn in', 'sworn in as'), 0.958960235118866),
#  (('emigrated to', 'emigrated from'), 0.9531527161598206),
#  (('negotiate', 'negotiate with'), 0.9521523118019104),
#  (('intervene', 'intervene in'), 0.95151287317276),
#  (('sworn-in', 'sworn in'), 0.9486343264579773),
#  (('concerned about', 'concerned with'), 0.9483494162559509),
#  (('involved with', 'involved in'), 0.9464719295501709),
#  (('file complaint', 'file complaint against'), 0.9460045099258423),
#  (('participate in', 'participate'), 0.9457226991653442),
#  (('appeal', 'appeal for'), 0.94526207447052),
#  (('campaign against', 'campaigns against'), 0.9440921545028687),
#  (('compete', 'compete for'), 0.9440404772758484),
#  (('was born in', 'born in'), 0.940864622592926),
#  (('countersue', 'countersued'), 0.9405544400215149),
#  (('tour', 'tour with'), 0.940220057964325),
#  (('concede', 'concede to'), 0.9365355968475342),
#  (('communicate with', 'communicate'), 0.9356071352958679),
#  (('consultant', 'consultant to'), 0.9350828528404236),
#  (('was born on', 'born on'), 0.934637725353241),
#  (('succeed', 'succeed to'), 0.9345054626464844),
#  (('is member of', 'member of'), 0.9344294667243958),
#  (('appeal to', 'appeal for'), 0.9332149624824524),
#  (('run for', 'running for'), 0.9319944977760315),
#  (('taught at', 'teach at'), 0.9305880665779114),
#  (('combine', 'combine with'), 0.9297321438789368),
#  (('commit', 'commit to'), 0.9265033602714539),
#  (('took office as', 'took office'), 0.9236714243888855),
#  (('graduate from', 'graduate'), 0.9212043285369873),
#  (('is replaced by', 'replaced by'), 0.9190704822540283),
#  (('graduate of', 'graduate'), 0.9183173179626465),
#  (('graduate in', 'graduate'), 0.9170823097229004),
#  (('advance to', 'advance'), 0.9161701798439026),
#  (('charge with', 'charged with'), 0.9147368669509888),
#  (('transfer', 'transfer to'), 0.9146340489387512),
#  (('charge', 'charge with'), 0.9137060046195984),
#  (('transferred to', 'transfer to'), 0.9133282899856567),
#  (('divide', 'divide into'), 0.912760853767395),
#  (('collaborate', 'collaborate closely with'), 0.9124327898025513),
#  (('hospitalized for', 'hospitalized at'), 0.9120815396308899),
#  (('travel', 'travel to'), 0.9117125868797302),
#  (('appoint as', 'appoint'), 0.9099354147911072),
#  (('testify to', 'testify'), 0.908906102180481),
#  (('worried about', 'concerned about'), 0.9085260629653931),
#  (('not engage', 'engage'), 0.907396137714386),
#  (('expand', 'expand upon'), 0.9064499139785767),
#  (('ran for', 'run for'), 0.9064374566078186),
#  (('meet', 'meet with'), 0.9054113626480103),
#  (('re-election', 're-elected'), 0.9050085544586182),
#  (('is child of', 'child of'), 0.9023725390434265),
#  (('divide on', 'divide'), 0.9007441401481628),
#  (('advance on', 'advance'), 0.9003211855888367),
#  (('protest against', 'protest'), 0.8996608853340149),
#  (('appointed as', 'appoint as'), 0.899625301361084),
#  (('turned over', 'turn over'), 0.8988434672355652),
#  (('campaign for', 'campaign'), 0.897434413433075),
#  (('invade', 'invasion'), 0.8971759676933289),
#  (('conflict with', 'conflict'), 0.8937994837760925),
#  (('concern', 'concerned about'), 0.8937929272651672),
#  (('propose', 'propose to'), 0.8930633664131165),
#  (('emphasis on', 'emphasis'), 0.8920932412147522),
#  (('returned to', 'return to'), 0.8918614387512207),
#  (('regard as', 'regard'), 0.891814112663269),
#  (('serve on', 'serve'), 0.8917727470397949),
#  (('sit', 'sit as'), 0.8883291482925415),
#  (('apologize to', 'apologize for'), 0.8874123096466064),
#  (('refer', 'refer to'), 0.8859280943870544),
#  (('plan', 'plan for'), 0.8858793377876282),
#  (('serve in', 'serve'), 0.885307252407074),
#  (('not release', 'release'), 0.8849496841430664),
#  (('apply', 'apply to'), 0.8823727965354919),
#  (('serve as', 'serve'), 0.8801830410957336),
#  (('testify before', 'testify'), 0.8795353174209595),
#  (('emphasize', 'emphasis'), 0.8784096837043762),
#  (('invests in', 'invest'), 0.8778938055038452),
#  (('advocate', 'advocate for'), 0.8774483799934387),
#  (('consist of', 'consists of'), 0.87703537940979),
#  (('engage in', 'engage'), 0.87594074010849),
#  (('pass', 'pass to'), 0.8756505250930786),
#  (('publicize', 'make public'), 0.8751030564308167),
#  (('shift', 'shift to'), 0.8725674748420715),
#  (('target', 'target of'), 0.8712215423583984),
#  (('described as', 'describe as'), 0.8704048991203308),
#  (('purchase', 'buy'), 0.8703044056892395),
#  (('graduated from', 'graduate from'), 0.8690220713615417),
#  (('plead guilty to', 'plead'), 0.8681287169456482),
#  (('married at', 'married in'), 0.8679344654083252),
#  (('respond to', 'respond'), 0.8666654229164124),
#  (('sit on', 'sit'), 0.8657734394073486),
#  (('rely on', 'relies on'), 0.8655897974967957),
#  (('analyze', 'analyse'), 0.8648166656494141),
#  (('resigning in', 'resign from'), 0.8639363050460815),
#  (('accused of', 'accused in'), 0.8632342219352722),
#  (('worry about', 'worried about'), 0.8601901531219482),
#  (('sponsor', 'co-sponsor'), 0.857733428478241),
#  (('subject of', 'subject to'), 0.8568491339683533),
#  (('introduce', 'introduce to'), 0.8563693761825562),
#  (('avoid', 'prevent'), 0.8560744524002075),
#  (('elected to', 'elected as'), 0.8559492826461792),
#  (('return', 'return to'), 0.8550573587417603),
#  (('not advocate', 'advocate'), 0.8545792102813721),
#  (('compete against', 'compete'), 0.8533186316490173),
#  (('compare to', 'compare'), 0.8529671430587769),
#  (('mark as', 'mark'), 0.8525234460830688),
#  (('set for', 'set'), 0.8523045182228088),
#  (('not secure', 'secure'), 0.851762592792511),
#  (('expand at', 'expand'), 0.8495126366615295),
#  (('committed to', 'commit to'), 0.8493097424507141),
#  (('intervention', 'intervene'), 0.8485773205757141),
#  (('accept with', 'accept'), 0.8479893803596497),
#  (('served as', 'serve as'), 0.8469711542129517),
#  (('work at', 'worked at'), 0.8459029197692871),
#  (('lose to', 'lose'), 0.8441359996795654),
#  (('agree to withdraw', 'withdraw'), 0.8429054617881775),
#  (('simplify', 'exemplify'), 0.8428793549537659),
#  (('married to', 'married in'), 0.8425499796867371),
#  (('begin', 'start'), 0.8421751260757446),
#  (('was against', 'against'), 0.8419346809387207),
#  (('part of', 'was part of'), 0.8415878415107727),
#  (('take office', 'took office'), 0.8407516479492188),
#  (('appealed to', 'appeal for'), 0.8399975895881653),
#  (('withdrew from', 'withdraw from'), 0.8388999104499817),
#  (('control', 'take control'), 0.8386967182159424),
#  (('married on', 'married to'), 0.8382328152656555),
#  (('acquit', 'vote to acquit'), 0.8380210995674133),
#  (('aim to comply with', 'comply with'), 0.8374050259590149),
#  (('move from', 'move to'), 0.8368223309516907),
#  (('push', 'push for'), 0.8364087343215942),
#  (('gave up', 'give up'), 0.8353759050369263),
#  (('acquiesce', 'acquit'), 0.835308849811554),
#  (('participated in', 'participate in'), 0.8351017832756042),
#  (('cut back', 'cut'), 0.8317850828170776),
#  (('argue for', 'argue'), 0.8313060998916626),
#  (('donate', 'donations'), 0.8306456208229065),
#  (('protect', 'provide protection for'), 0.8304934501647949),
#  (('bring', 'bring in'), 0.8301994800567627),
#  (('accepted as', 'accept as'), 0.8295527696609497),
#  (('stay with', 'live with'), 0.8286875486373901),
#  (('rank', 'rank among'), 0.8285362720489502),
#  (('positive impact on', 'negative impact on'), 0.8278260231018066),
#  (('nominate', 'nomination'), 0.8219301104545593),
#  (('cut out', 'cut'), 0.8199316263198853),
#  (('express', 'express support for'), 0.8189308047294617),
#  (('lend', 'lend name to'), 0.8185381293296814),
#  (('play key role in', 'play role in'), 0.8182803988456726),
#  (('defeated in', 'defeated by'), 0.8179638981819153),
#  (('write on', 'write'), 0.8175932168960571),
#  (('vote for', 'vote on'), 0.8173676133155823),
#  (('call on', 'call'), 0.8173375725746155),
#  (('clerk for', 'clerked at'), 0.8150251507759094),
#  (('graduate student at', 'graduate in'), 0.8132579326629639),
#  (('victory in', 'victory over'), 0.8129860162734985),
#  (('became active in', 'be active in'), 0.8101810216903687),
#  (('identify as', 'identify'), 0.8096927404403687),
#  (('sell', 'sale'), 0.8095656633377075),
#  (('relocate to', 'move to'), 0.807546079158783),
#  (('move', 'move from'), 0.8067998886108398),
#  (('run', 'run for'), 0.8062939643859863),
#  (('meet at', 'meet'), 0.806293249130249),
#  (('swear in', 'swore in'), 0.806182324886322),
#  (('file for', 'file'), 0.8032491207122803),
#  (('donated to', 'donations'), 0.8020433187484741),
#  (('call for resignation', 'resign'), 0.8016931414604187),
#  (('borrow', 'lend'), 0.801498532295227),
#  (('ordered by', 'order'), 0.8010826706886292),
#  (('partner with', 'partnership with'), 0.7998043298721313),
#  (('carry', 'carry out'), 0.7988229393959045),
#  (('threaten to veto', 'veto'), 0.7985596656799316),
#  (('appear on', 'appear'), 0.7985191941261292),
#  (('take responsibility for', 'claim responsibility for'), 0.7985064387321472),
#  (('sign deal with', 'sign'), 0.7978366017341614),
#  (('sit in', 'sit'), 0.7977802753448486),
#  (('not greet', 'greet'), 0.7974902987480164),
#  (('moved to', 'move to'), 0.7972994446754456),
#  (('serve alongside', 'serve'), 0.7970637679100037),
#  (('enrolled in', 'enroll'), 0.7967832684516907),
#  (('call for', 'call'), 0.7960991859436035),
#  (('argue against', 'argue'), 0.795974612236023),
#  (('gain influence', 'influence'), 0.7958461046218872),
#  (('confirm', 'not confirm'), 0.7956169843673706),
#  (('move in', 'live in'), 0.7953092455863953),
#  (('speak', 'speak about'), 0.7939033508300781),
#  (('cut ties with', 'strengthen ties with'), 0.7929714918136597),
#  (('demand investigation', 'demand'), 0.792746365070343),
#  (('talk about', 'speak about'), 0.7926320433616638),
#  (('express desire', 'desire'), 0.7925014495849609),
#  (('not ratify', 'ratify'), 0.7923213243484497),
#  (('run on', 'run'), 0.7917065024375916),
#  (('choose', 'decide'), 0.7914396524429321),
#  (('urge toward', 'urge'), 0.7914208173751831),
#  (('finish', 'finish behind'), 0.7913380265235901),
#  (('served under', 'served as'), 0.7909362316131592),
#  (('replace', 'replaced by'), 0.7899508476257324),
#  (('examine', 'inspect'), 0.7899472713470459),
#  (('accede to pressure from', 'pressure'), 0.7894726395606995),
#  (('appear at', 'appear'), 0.7888274788856506),
#  (('friend of', 'friend with'), 0.7881754040718079),
#  (('demand resignation', 'call for resignation'), 0.7868586778640747),
#  (('allowed release', 'release'), 0.7829549908638),
#  (('loss', 'lose'), 0.7817452549934387),
#  (('counter', 'countersue'), 0.7811612486839294),
#  (('produce', 'co-produce'), 0.7801792025566101),
#  (('agree to', 'agree'), 0.7800841927528381),
#  (('decrease', 'reduce'), 0.7788933515548706),
#  (('work', 'work for'), 0.7781674265861511),
#  (('agree to run for', 'run for'), 0.7776517868041992),
#  (('teach', 'teach at'), 0.7773446440696716),
#  (('open to', 'open'), 0.7753462791442871),
#  (('spouse', 'married to'), 0.7752906680107117),
#  (('split', 'separate'), 0.7748508453369141),
#  (('reelected to', 'elected to'), 0.7735928893089294),
#  (('speak to', 'speak'), 0.7724545001983643),
#  (('grow', 'grow faster than'), 0.7711647748947144),
#  (('count', 'counted on'), 0.7707148194313049),
#  (('descend from', 'descended from'), 0.770390510559082),
#  (('leave', 'stay'), 0.7697561979293823),
#  (('condemned as', 'condemn'), 0.7693914175033569),
#  (('co-author', 'author'), 0.76932293176651),
#  (('involve', 'involved with'), 0.7684246301651001),
#  (('cover', 'cover up'), 0.7674890756607056),
#  (('live', 'live at'), 0.7670984268188477),
#  (('investigate', 'investigated by'), 0.7669989466667175),
#  (('be in', 'appear in'), 0.7664201855659485),
#  (('owe', 'repay'), 0.7660362720489502),
#  (('campaigned for', 'campaign for'), 0.7641227841377258),
#  (('describe', 'described as'), 0.7638968825340271),
#  (('vote to convict', 'convict'), 0.7618760466575623),
#  (('move closer to', 'move'), 0.7618186473846436),
#  (('ask', 'ask about'), 0.761363685131073),
#  (('host', 'co-host'), 0.7610374093055725),
#  (('work as', 'work'), 0.7608237862586975),
#  (('believe', 'believe in'), 0.7605984807014465),
#  (('restrict', 'call for restrictions on'), 0.7601012587547302),
#  (('responsible for', 'take responsibility for'), 0.7599155902862549),
#  (('co-producer', 'co-produce'), 0.7588584423065186),
#  (('open up', 'open to'), 0.7586910724639893),
#  (('met in', 'meet'), 0.7583509087562561),
#  (('merge', 'combine'), 0.7580678462982178),
#  (('safeguard', 'protect'), 0.7576470375061035),
#  (('remove', 'delete'), 0.7576206922531128),
#  (('hear', 'hear about'), 0.7567188143730164),
#  (('move quickly', 'move'), 0.7564650774002075),
#  (('care', 'cared by'), 0.7546015977859497),
#  (('drop out', 'drop'), 0.7540709972381592),
#  (('help pass', 'pass'), 0.7537115216255188),
#  (('invited to speak at', 'speak at'), 0.7534103393554688),
#  (('remain in', 'remain'), 0.7524815201759338),
#  (('give speech at', 'speak at'), 0.7511515617370605),
#  (('employed at', 'work at'), 0.7504884600639343),
#  (('worked in', 'worked at'), 0.7503498792648315),
#  (('is located in', 'locate in'), 0.7503172159194946),
#  (('seated by', 'sit'), 0.7471482157707214),
#  (('composed of', 'consist of'), 0.7467039227485657),
#  (('accuse', 'accused of'), 0.7466747164726257),
#  (('criticism of', 'faced criticism'), 0.7461965084075928),
#  (('work on', 'work'), 0.7460901737213135),
#  (('make trips', 'travel'), 0.7455562949180603),
#  (('participates in', 'participate in'), 0.7455161213874817),
#  (('nominated by', 'nomination'), 0.7451130151748657),
#  (('prove', 'prove to be'), 0.7450241446495056),
#  (('talk', 'talk about'), 0.7444655299186707),
#  (('vote', 'vote for'), 0.7442952394485474),
#  (('back', 'back down'), 0.7440305948257446),
#  (('no nominee for', 'nomination'), 0.742476224899292),
#  (('consolidate', 'merge'), 0.7401257157325745),
#  (('extend', 'expand'), 0.7397940158843994),
#  (('criticize', 'criticism of'), 0.7387590408325195),
#  (('reach out to', 'reach'), 0.7385830879211426),
#  (('violate', 'bring into violation'), 0.7385621666908264),
#  (('answer', 'question'), 0.7374057769775391),
#  (('work with', 'work as'), 0.7367773652076721),
#  (('exclude', 'ignore'), 0.7352941036224365),
#  (('contributed to', 'contribute to'), 0.7344242930412292),
#  (('reject', 'rejected by'), 0.7335692644119263),
#  (('arrive in', 'bring in'), 0.7304345965385437),
#  (('convicted of', 'accused of'), 0.7303169965744019),
#  (('keep', 'stay'), 0.7300975918769836),
#  (('violations', 'violate'), 0.7300690412521362),
#  (('wage', 'pay'), 0.7299829721450806),
#  (('defend', 'defender of'), 0.7296291589736938),
#  (('sentenced to', 'convicted of'), 0.7293906807899475),
#  (('agree to work', 'work'), 0.7293286919593811),
#  (('regarded as', 'regard as'), 0.7283728122711182),
#  (('turn down', 'turn over'), 0.7265492677688599),
#  (('lie', 'lied to'), 0.7257711887359619),
#  (('partner-in-charge', 'partner with'), 0.7246279716491699),
#  (('lead to', 'lead'), 0.7244123816490173),
#  (('ran against', 'ran for'), 0.7234554886817932),
#  (('assign', 'assigned to'), 0.7232312560081482),
#  (('vote in favor of', 'vote against'), 0.722281277179718),
#  (('study at', 'graduate student at'), 0.7213987112045288),
#  (('prohibit', 'restrict'), 0.7207961082458496),
#  (('intensify', 'unify'), 0.7204732894897461),
#  (('draw', 'draw upon'), 0.7201899290084839),
#  (('be with', 'live with'), 0.7198930382728577),
#  (('fail', 'succeed'), 0.7196337580680847),
#  (('ban', 'prohibit'), 0.7189844250679016),
#  (('gathered in', 'gather'), 0.7189754843711853),
#  (('deny', 'deny entry to'), 0.7175210118293762),
#  (('reside in', 'live in'), 0.7166265249252319),
#  (('take leave from', 'leave'), 0.7166141867637634),
#  (('overhaul', 'rebuild'), 0.7158840894699097),
#  (('criminalize', 'prosecute'), 0.7151591777801514),
#  (('employ', 'employed at'), 0.7150933742523193),
#  (('fight', 'defeat'), 0.7140647172927856),
#  (('ordered to pay', 'pay'), 0.7140114903450012),
#  (('appearances on', 'guest appearances on'), 0.7135653495788574),
#  (('wipe', 'erase'), 0.7127255797386169),
#  (('recognize', 'identify'), 0.7126197218894958),
#  (('abandonment of', 'abandon'), 0.7112093567848206),
#  (('disregard', 'ignore'), 0.7110352516174316),
#  (('arrange', 'order'), 0.7108868956565857),
#  (('learned of', 'learn'), 0.7107516527175903),
#  (('loaning money to', 'lend'), 0.71007239818573),
#  (('mitigate', 'prevent'), 0.7086527943611145),
#  (('fought against', 'fight'), 0.7082975506782532),
#  (('recruited to', 'recruit'), 0.7072120308876038),
#  (('combat', 'fight'), 0.706985592842102),
#  (('could build', 'build'), 0.7063360214233398),
#  (('failure to prevent', 'prevent'), 0.7063106894493103),
#  (('go bankrupt', 'file for bankruptcy'), 0.7059601545333862),
#  (('widen', 'expand'), 0.7054657340049744),
#  (('expressed support for', 'support'), 0.7051887512207031),
#  (('leader of', 'president of'), 0.7042621970176697),
#  (('hide', 'reveal'), 0.704112708568573),
#  (('use', 'never used'), 0.7037127614021301),
#  (('supporter of', 'fan of'), 0.7035139799118042),
#  (('plant', 'flower'), 0.7031400203704834),
#  (('treat', 'treated with'), 0.7031091451644897),
#  (('categorize', 'classify'), 0.7030382752418518),
#  (('enlist', 'recruit'), 0.7019346356391907),
#  (('originate from', 'descended from'), 0.7019150853157043),
#  (('seize power from', 'seize'), 0.7017313241958618),
#  (('lobby against', 'campaign against'), 0.7011229395866394),
#  (('create', 'generate'), 0.7005926966667175),
#  (('allow', 'restrict'), 0.7002620100975037),
#  (('recover', 'reinstate'), 0.7001971006393433),
#  (('focus', 'focus on'), 0.7000711560249329)]

# %%
pairs = [i[0] for i in sorted_similarities2]
mapping_22 = {}
for pair in pairs:
    mapping_22[pair[0]] = pair[1]

# %%
final2 = {}
for r in raw_relations:
    tmp= mapping_1[r]
    if tmp in mapping_22:
        final2[r]= mapping_22[tmp]
    else:
        final2[r] = tmp

# %%
unique_relations2 = len(set(final2.values()))
unique_relations2
# Out:
# 1055

# %%
len(unique_relations) - unique_relations2
# Out:
# 251

# %%
with open("relation_mapping_sentence_transformer.csv", "w") as f:
   for key in final2.keys():
        f.write("%s,%s\n"%(key,final2[key]))
